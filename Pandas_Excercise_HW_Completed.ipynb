# %% [markdown]
# Import the pandas library
# Read the data company.csv in pandas

# %%
import pandas as pd

# %%
company = pd.read_csv(r"C:\Users\mailk\OneDrive\Desktop\AI and ML\company.csv")

# %% [markdown]
# Find the dimension of given data

# %%
company.shape
# Out:
# (148, 6)

# %% [markdown]
# List down all the columns in data frame

# %%
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
company.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# List the top 10 rows in datframe

# %%
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
company.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %%
company.tail(15)
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# ...

# %% [markdown]
# List the last 15 rows in datframe

# %%
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# ...

# %% [markdown]
# Find the number of rows in dataframe

# %%
# Out:
# 148

# %%
company.shape[0]
# Out:
# 148

# %% [markdown]
# Check the information of dataframe

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
# Company    140 non-null object
# Age        130 non-null float64
# Salary     124 non-null float64
# Place      134 non-null object
# Country    148 non-null object
# Gender     148 non-null int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.0+ KB

# %%
company.describe
# Out:
# <bound method NDFrame.describe of      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]>

# %% [markdown]
# Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
company.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
company.iloc[20:101,0:2]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig iloc

# %%
# Out:
#             Company   Age
# 20              TCS  37.0
# 21          Infosys  50.0
# 22              TCS  21.0
# 23          Infosys   NaN
# 24              TCS   NaN
# 25          Infosys  23.0
# 26              TCS  34.0
# 27              CTS  45.0
# 28              CTS  23.0
# 29              CTS  35.0
# 30              CTS  46.0
# 31              CTS  20.0
# 32          Infosys  45.0
# 33              TCS  36.0
# 34          Infosys  26.0
# 35              TCS  35.0
# 36              TCS  32.0
# 37              NaN  35.0
# 38              TCS  34.0
# 39          Infosys  41.0
# 40              TCS  24.0
# 41          Infosys   NaN
# 42              TCS   NaN
# 43          Infosys  25.0
# 44              TCS  35.0
# 45              CTS  46.0
# 46              CTS  24.0
# 47              CTS  32.0
# 48              CTS  43.0
# 49              CTS  19.0
# ..              ...   ...
# 70  Infosys Pvt Lmt  21.0
# 71              TCS  34.0
# 72              TCS  24.0
# ...

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig loc

# %%
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# 25   Infosys  23.0
# 26       TCS  34.0
# 27       CTS  45.0
# 28       CTS  23.0
# 29       CTS  35.0
# 30       CTS  46.0
# 31       CTS  20.0
# 32   Infosys  45.0
# 33       TCS  36.0
# 34   Infosys  26.0
# 35       TCS  35.0
# 36       TCS  32.0
# 37       NaN  35.0
# 38       TCS  34.0
# 39   Infosys  41.0
# 40       TCS  24.0
# 41   Infosys   NaN
# 42       TCS   NaN
# 43   Infosys  25.0
# 44       TCS  35.0
# 45       CTS  46.0
# 46       CTS  24.0
# 47       CTS  32.0
# 48       CTS  43.0
# 49       CTS  19.0
# ..       ...   ...
# 71       TCS  34.0
# 72       TCS  24.0
# 73   Infosys  34.0
# 74       TCS  37.0
# 75   Infosys  44.0
# 76       TCS  32.0
# 77   Infosys   NaN
# 78       TCS   NaN
# 79   Infosys  26.0
# 80       TCS  32.0
# 81       CTS  43.0
# 82       CTS  22.0
# 83       CTS  33.0
# 84       CTS  43.0
# 85       CTS  17.0
# ...

# %% [markdown]
# Chage the data in 100 row and Place as 'Noida'

# %%
# Out:
# Company      CTS
# Age           22
# Salary       NaN
# Place      Noida
# Country    India
# Gender         0
# Name: 100, dtype: object

# %%
company.loc[100:100]
# Out:
#     Company   Age  Salary   Place Country  Gender
# 100     CTS  22.0     NaN  Cochin   India       0

# %%
company.loc[100:100,'Place'] = 'Noida'

# %%
company.loc[100:100]
# Out:
#     Company   Age  Salary  Place Country  Gender
# 100     CTS  22.0     NaN  Noida   India       0

# %% [markdown]
# Change the column 'Place' to 'City'

# %%
company.rename(columns={'Place':'City'}, inplace = True)

# %%
company.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country', 'Gender'], dtype='object')

# %%
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# List down the unique data in each columns and find length of unique data

# %%
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# Gender      2
# dtype: int64

# %%
for i in company:
    print(i, company[i].nunique())
# Out:
# Company 6
# Age 29
# Salary 40
# City 11
# Country 1
# Gender 2

# %%
company['Company'].value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Congnizant                    2
# Tata Consultancy Services     2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Congnizant                    2
# Tata Consultancy Services     2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64
# 22.0    16
# 33.0    13
# 44.0    10
# 21.0     8
# 23.0     8
# 34.0     8
# 32.0     7
# 35.0     6
# 0.0      6
# 41.0     5
# 43.0     4
# 24.0     4
# 45.0     4
# 25.0     3
# 36.0     3
# 40.0     3
# 31.0     3
# 20.0     3
# 30.0     2
# 26.0     2
# 37.0     2
# 46.0     2
# 50.0     2
# 18.0     1
# 17.0     1
# 38.0     1
# 19.0     1
# 51.0     1
# 54.0     1
# Name: Age, dtype: int64
# 3000.0    9
# 5000.0    6
# 4034.0    5
# 8202.0    5
# 5034.0    5
# 3184.0    4
# 7084.0    4
# 8787.0    4
# 1234.0    4
# 3045.0    4
# 5835.0    4
# 9024.0    4
# 8943.0    4
# 9284.0    4
# 2034.0    4
# 4824.0    4
# 2934.0    4
# 1089.0    4
# 2300.0    4
# 8345.0    4
# 7000.0    3
# 3030.0    3
# 8000.0    3
# 9000.0    3
# 6000.0    3
# ...

# %%
company['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
company["Company"].replace({'Tata Consultancy Services':'TCS','Congnizant':'CTS', 'Infosys Pvt Lmt':'Infosys'}, inplace= True)

# %%
company['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan], dtype=object)

# %% [markdown]
# Rename all the possible labels of column in Company as three labels
# TCS
# CTS
# Infosys

# %%
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %% [markdown]
# Where ever you see age as 0 replace with NA
#
# ##Hint df[df.Age==20] = np.isnan

# %%
company[company["Age"] == 0] = np.isnan

# %%
company[company["Age"] == 0]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country, Gender]
# Index: []

# %%
company["Age"]
# Out:
# 0      20
# 1      30
# 2      35
# 3      40
# 4      23
#        ..
# 143    33
# 144    22
# 145    44
# 146    33
# 147    22
# Name: Age, Length: 148, dtype: object

# %% [markdown]
# Check how many duplicated data is there?

# %%
# Out:
# 9

# %%
company[company.duplicated()].count()[0]
# Out:
# 9

# %%
company = company.drop_duplicates()

# %%
company
# Out:
#      Company Age Salary      City Country Gender
# 0        TCS  20    NaN   Chennai   India      0
# 1    Infosys  30    NaN    Mumbai   India      0
# 2        TCS  35   2300  Calcutta   India      0
# 3    Infosys  40   3000     Delhi   India      0
# 4        TCS  23   4000    Mumbai   India      0
# ..       ...  ..    ...       ...     ...    ...
# 142  Infosys  22   8202    Mumbai   India      0
# 143      TCS  33   9024  Calcutta   India      1
# 145  Infosys  44   4034     Delhi   India      1
# 146      TCS  33   5034    Mumbai   India      1
# 147  Infosys  22   8202    Cochin   India      0
#
# [139 rows x 6 columns]

# %% [markdown]
# Remove all duplicated rowise data

# %% [markdown]
# Remove the column 'Country'

# %%
# Out:
#      Company  Age Salary        City Country Gender
# 0        TCS   20    NaN     Chennai   India      0
# 1    Infosys   30    NaN      Mumbai   India      0
# 2        TCS   35   2300    Calcutta   India      0
# 3    Infosys   40   3000       Delhi   India      0
# 4        TCS   23   4000      Mumbai   India      0
# 5    Infosys  NaN   5000    Calcutta   India      0
# 6        TCS  NaN   6000     Chennai   India      1
# 7    Infosys   23   7000      Mumbai   India      1
# 8        TCS   34   8000    Calcutta   India      1
# 9        CTS   45   9000       Delhi   India      0
# 10       CTS   23    NaN      Mumbai   India      0
# 11       CTS   34   1089    Calcutta   India      0
# 12       CTS   45    NaN     Chennai   India      0
# 13       CTS   18   1234      Mumbai   India      0
# 14   Infosys   40   3000    Calcutta   India      0
# 15       TCS   23   3000       Delhi   India      0
# 16   Infosys   23   3030  Podicherry   India      0
# ...

# %%
company.head(5)
# Out:
#    Company Age Salary      City Country Gender
# 0      TCS  20    NaN   Chennai   India      0
# 1  Infosys  30    NaN    Mumbai   India      0
# 2      TCS  35   2300  Calcutta   India      0
# 3  Infosys  40   3000     Delhi   India      0
# 4      TCS  23   4000    Mumbai   India      0

# %%
company.drop('Country', axis = 'columns', inplace = True)
# Out:
# C:\Work\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
company.head()
# Out:
#    Company Age Salary      City Gender
# 0      TCS  20    NaN   Chennai      0
# 1  Infosys  30    NaN    Mumbai      0
# 2      TCS  35   2300  Calcutta      0
# 3  Infosys  40   3000     Delhi      0
# 4      TCS  23   4000    Mumbai      0

# %% [markdown]
# Remove the row number 137

# %%
# Out:
#      Company  Age Salary        City Country Gender
# 0        TCS   20    NaN     Chennai   India      0
# 1    Infosys   30    NaN      Mumbai   India      0
# 2        TCS   35   2300    Calcutta   India      0
# 3    Infosys   40   3000       Delhi   India      0
# 4        TCS   23   4000      Mumbai   India      0
# 5    Infosys  NaN   5000    Calcutta   India      0
# 6        TCS  NaN   6000     Chennai   India      1
# 7    Infosys   23   7000      Mumbai   India      1
# 8        TCS   34   8000    Calcutta   India      1
# 9        CTS   45   9000       Delhi   India      0
# 10       CTS   23    NaN      Mumbai   India      0
# 11       CTS   34   1089    Calcutta   India      0
# 12       CTS   45    NaN     Chennai   India      0
# 13       CTS   18   1234      Mumbai   India      0
# 14   Infosys   40   3000    Calcutta   India      0
# 15       TCS   23   3000       Delhi   India      0
# 16   Infosys   23   3030  Podicherry   India      0
# ...

# %%
company = company.drop(company.index[[137]])

# %%
company
# Out:
#      Company Age Salary       City Gender
# 0        TCS  20    NaN    Chennai      0
# 1    Infosys  30    NaN     Mumbai      0
# 2        TCS  35   2300   Calcutta      0
# 3    Infosys  40   3000      Delhi      0
# 4        TCS  23   4000     Mumbai      0
# ..       ...  ..    ...        ...    ...
# 140  Infosys  44   4034  Hyderabad      0
# 141      TCS  33   5034   Calcutta      0
# 142  Infosys  22   8202     Mumbai      0
# 143      TCS  33   9024   Calcutta      1
# 145  Infosys  44   4034      Delhi      1
#
# [137 rows x 5 columns]

# %%
company.Company.value_counts()
# Out:
# TCS                51
# Infosys            42
# CTS                35
# <ufunc 'isnan'>     1
# Name: Company, dtype: int64

# %% [markdown]
# Find number of each labels in Company

# %%
# Out:
# TCS                52
# Infosys            43
# CTS                35
# <ufunc 'isnan'>     1
# Name: Company, dtype: int64

# %% [markdown]
# Find number of each labels in City

# %%
# Out:
# Mumbai             33
# Calcutta           30
# Delhi              13
# Chennai            13
# Cochin             12
# Noida               9
# Hyderabad           8
# Podicherry          2
# Pune                2
# Nagpur              1
# <ufunc 'isnan'>     1
# Bhopal              1
# Name: City, dtype: int64

# %%
company.City.value_counts()
# Out:
# Mumbai             32
# Calcutta           30
# Delhi              13
# Chennai            13
# Cochin             11
# Noida               9
# Hyderabad           8
# Pune                2
# Podicherry          2
# <ufunc 'isnan'>     1
# Nagpur              1
# Bhopal              1
# Name: City, dtype: int64

# %% [markdown]
# Find Number of Null Values in each column

# %%
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Country     0
# Gender      0
# dtype: int64

# %%
company.isna().sum()
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Gender      0
# dtype: int64

# %% [markdown]
# Remove all Null values in Salary

# %%
company = company.Salary.dropna()

# %%
company
# Out:
# 2      2300
# 3      3000
# 4      4000
# 5      5000
# 6      6000
#        ...
# 140    4034
# 141    5034
# 142    8202
# 143    9024
# 145    4034
# Name: Salary, Length: 114, dtype: object

# %%
company.Company.mode()
# Out:
# 0    TCS
# dtype: object

# %%
company['Company'].fillna(company['Company'].mode([0]),inplace=True)

# %%
company.Company.value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %% [markdown]
# Replace the Null values in Comapany with mode

# %%
company[company.Salary.isna()]
# Out:
#      Company   Age  Salary      Place Country  Gender
# 0        TCS  20.0     NaN    Chennai   India       0
# 1    Infosys  30.0     NaN     Mumbai   India       0
# 10       CTS  23.0     NaN     Mumbai   India       0
# 12       CTS  45.0     NaN    Chennai   India       0
# 18       TCS  22.0     NaN    Chennai   India       0
# 19   Infosys  32.0     NaN     Mumbai   India       0
# 36       TCS  32.0     NaN      Noida   India       0
# 37       NaN  35.0     NaN  Hyderabad   India       0
# 46       CTS  24.0     NaN   Calcutta   India       0
# 48       CTS  43.0     NaN     Mumbai   India       0
# 66       CTS  41.0     NaN   Calcutta   India       0
# 72       TCS  24.0     NaN   Calcutta   India       0
# 73   Infosys  34.0     NaN      Delhi   India       0
# 82       CTS  22.0     NaN       Pune   India       0
# 84       CTS  43.0     NaN     Mumbai   India       0
# 90       TCS  21.0     NaN     Mumbai   India       0
# ...

# %%
company['Salary'].fillna(company['Salary'].median(), inplace=True)

# %%
company[company.Salary.isna()]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, Place, Country, Gender]
# Index: []

# %% [markdown]
# Replace the null value in Salary with median

# %%
company['Age'].fillna(company['Age'].mean(), inplace=True)

# %%
company[company.Age.isna()]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, Place, Country, Gender]
# Index: []

# %% [markdown]
# Replace the null value in age with mean

# %% [markdown]
# Filter the data with age>40 and Salary<5000

# %%
# Out:
#      Company   Age  Salary       City Country Gender
# 21   Infosys  50.0  3184.0      Delhi   India      0
# 32   Infosys  45.0  4034.0   Calcutta   India      0
# 39   Infosys  41.0  3000.0     Mumbai   India      0
# 50   Infosys  41.0  3000.0    Chennai   India      0
# 57   Infosys  51.0  3184.0  Hyderabad   India      0
# 68   Infosys  43.0  4034.0     Mumbai   India      0
# 75   Infosys  44.0  3000.0     Cochin   India      0
# 86   Infosys  41.0  3000.0      Delhi   India      0
# 93   Infosys  54.0  3184.0     Mumbai   India      0
# 104  Infosys  44.0  4034.0      Delhi   India      0
# 122  Infosys  44.0  3234.0     Mumbai   India      0
# 129  Infosys  50.0  3184.0   Calcutta   India      0
# 138      CTS  44.0  3033.0     Cochin   India      0
# 140  Infosys  44.0  4034.0  Hyderabad   India      0
# 145  Infosys  44.0  4034.0      Delhi   India      1

# %%
filt = (company['Age'] > 40) & (company['Salary'] < 5000)

# %%
company[filt]
# Out:
#      Company   Age  Salary      Place Country  Gender
# 21   Infosys  50.0  3184.0      Delhi   India       0
# 32   Infosys  45.0  4034.0   Calcutta   India       0
# 39   Infosys  41.0  3000.0     Mumbai   India       0
# 50   Infosys  41.0  3000.0    Chennai   India       0
# 57   Infosys  51.0  3184.0  Hyderabad   India       0
# 68   Infosys  43.0  4034.0     Mumbai   India       0
# 75   Infosys  44.0  3000.0     Cochin   India       0
# 86   Infosys  41.0  3000.0      Delhi   India       0
# 93   Infosys  54.0  3184.0     Mumbai   India       0
# 104  Infosys  44.0  4034.0      Delhi   India       0
# 122  Infosys  44.0  3234.0     Mumbai   India       0
# 129  Infosys  50.0  3184.0   Calcutta   India       0
# 138      CTS  44.0  3033.0     Cochin   India       0
# 140  Infosys  44.0  4034.0  Hyderabad   India       0
# 145  Infosys  44.0  4034.0      Delhi   India       1

# %%
company[{'Salary'}].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Draw an histogram chart for age, Salary

# %% [markdown]
# Draw the pie chart for place and Company

# %%
import matplotlib.pyplot as plt

# %%
place_count = company.Place.value_counts()

# %%
place_count
# Out:
# Mumbai        37
# Calcutta      33
# Delhi         14
# Chennai       14
# Cochin        13
# Noida          8
# Hyderabad      8
# Podicherry     3
# Pune           2
# Nagpur         1
# Bhopal         1
# Name: Place, dtype: int64

# %%
company.groupby('Place').count()
# Out:
#             Company  Age  Salary  Country  Gender
# Place
# Bhopal            1    1       1        1       1
# Calcutta         31   33      33       33      33
# Chennai          13   14      14       14      14
# Cochin           13   13      13       13      13
# Delhi            13   14      14       14      14
# Hyderabad         7    8       8        8       8
# Mumbai           36   37      37       37      37
# Nagpur            1    1       1        1       1
# Noida             7    8       8        8       8
# Podicherry        3    3       3        3       3
# Pune              2    2       2        2       2

# %%
place_count
# Out:
# [37, 33, 14, 14, 13, 8, 8, 3, 2, 1, 1]

# %%
place_name = list(company.Place.unique())

# %%
company.Place.unique()
# Out:
# array(['Chennai', 'Mumbai', 'Calcutta', 'Delhi', 'Podicherry', 'Cochin',
#        nan, 'Noida', 'Hyderabad', 'Bhopal', 'Nagpur', 'Pune'],
#       dtype=object)

# %%
place_name
# Out:
# ['Chennai',
#  'Mumbai',
#  'Calcutta',
#  'Delhi',
#  'Podicherry',
#  'Cochin',
#  nan,
#  'Noida',
#  'Hyderabad',
#  'Bhopal',
#  'Nagpur',
#  'Pune']

# %%
plt.pie(place_count, labels = place_count)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f79b3fde50>,
# ...
#  [Text(0.7114468821163326, 0.8389537138167691, '37'),
#   Text(-0.8868772595640112, 0.650729380363473, '33'),
#   Text(-0.9812752486078591, -0.4970904208185715, '14'),
#   Text(-0.47395002926996244, -0.9926587378122463, '14'),
#   Text(0.20510616883264737, -1.0807087764549679, '13'),
#   Text(0.6915842385680739, -0.8554012163682125, '8'),
#   Text(0.9568970590242597, -0.5425384948837481, '8'),
#   Text(1.0636227747227744, -0.28054695345169317, '3'),
#   Text(1.0891347791278971, -0.15422526671731457, '2'),
#   Text(1.0972803358619914, -0.07730371614997245, '1'),
#   Text(1.099697705747415, -0.025786740272311266, '1')])

# %%
company_count = company.Company.value_counts()

# %%
company_count
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
plt.pie(company_count, labels = company_count)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f79b45ee50>,
# ...
#  [Text(0.363306995924972, 1.0382716536205603, '55'),
#   Text(-1.0209265158538015, -0.4095229532353689, '47'),
#   Text(0.7237325630784134, -0.8283786435803078, '38')])

# %% [markdown]
# Find the mean, count, median of salary with repective to the place

# %%
# Out:
#                         mean  count  median
# City
# <ufunc 'isnan'>  5009.000000      1  5009.0
# Bhopal           7000.000000      1  7000.0
# Calcutta         5115.400000     25  4824.0
# Chennai          5824.200000     10  5917.5
# Cochin           5053.000000     12  5017.0
# Delhi            4925.545455     11  4034.0
# Hyderabad        4382.833333      6  3609.0
# Mumbai           4895.269231     26  4429.0
# Nagpur           8000.000000      1  8000.0
# Noida            4387.000000      7  4000.0
# Podicherry       6157.000000      2  6157.0
# Pune             9000.000000      1  9000.0

# %%
company.groupby('Place').Salary.aggregate({'mean', 'count', 'median'})
# Out:
#                    mean  count  median
# Place
# Bhopal      7000.000000      1  7000.0
# Calcutta    5028.363636     33  5000.0
# Chennai     5876.142857     14  5635.0
# Cochin      5048.923077     13  5000.0
# Delhi       4801.857143     14  4034.0
# Hyderabad   4537.125000      8  4517.0
# Mumbai      4896.486486     37  5000.0
# Nagpur      8000.000000      1  8000.0
# Noida       4463.625000      8  4500.0
# Podicherry  4782.666667      3  3030.0
# Pune        7000.000000      2  7000.0

# %% [markdown]
# Find the mean age with repective to the Company

# %%
# Out:
# Company
# <ufunc 'isnan'>    32.292929
# CTS                33.160000
# Infosys            33.950013
# TCS                31.137901
# Name: Age, dtype: float64

# %%
company.groupby('Company').Age.aggregate({'mean'})
# Out:
#               mean
# Company
# CTS      31.631579
# Infosys  31.784615
# TCS      28.925035
