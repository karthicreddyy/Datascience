# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\mailk\\OneDrive\\Desktop\\AI and ML\\02. Pre-Processing-2-20210705T030211Z-001\\02. Pre-Processing-2\\Activity\\train_v9rqX0R.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
data_copy = data.copy()

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.Item_Fat_Content.value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
data.Item_Fat_Content.replace({'LF':'Low Fat', 'reg': 'Regular', 'low fat':'Low Fat'}, inplace=True)

# %%
data.Item_Fat_Content.value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
data.Item_Identifier.value_counts()
# Out:
# FDG33    10
# FDW13    10
# FDG09     9
# FDX20     9
# NCJ30     9
#          ..
# FDK57     1
# FDQ60     1
# FDY43     1
# FDE52     1
# DRF48     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.Item_Identifier[data['Item_Weight'].isna()].duplicated().sum()
# Out:
# 321

# %%
data.Item_Identifier.duplicated().sum()
# Out:
# 6964

# %%
data[data['Item_Weight'].isna()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
data.Outlet_Establishment_Year.value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
data[['Outlet_Establishment_Year']][data['Item_Weight'].isna()].value_counts()
# Out:
# Outlet_Establishment_Year
# 1985                         1463
# dtype: int64

# %%
data.Outlet_Type.value_counts(dropna=False)
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
## This does not add value to the outlet type, but just to practice
data.Outlet_Type.replace({'Supermarket Type1':5,
                          'Grocery Store':4,
                          'Supermarket Type3':3,
                          'Supermarket Type2':2                         
                         },inplace=True)

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.Outlet_Size.value_counts(dropna=False)
# Out:
# Medium    2793
# NaN       2410
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
## This does not add value to the outlet Size, but just to practice
data.Outlet_Size.replace({'Medium':2,
                          'Small':1,
                          'High':3
                         },inplace=True)

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.Outlet_Identifier.nunique()
# Out:
# 10

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data[data['Item_Weight'].isna()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
Item_Type_weight = dict(data.groupby(['Item_Type']).Item_Weight.mean())

# %%
Item_Type_weight
# Out:
# {'Baking Goods': 12.277108208955255,
#  'Breads': 11.3469362745098,
#  'Breakfast': 12.768202247191002,
#  'Canned': 12.305705009276451,
#  'Dairy': 13.42606890459367,
#  'Frozen Foods': 12.867061281337076,
#  'Fruits and Vegetables': 13.224769381746881,
#  'Hard Drinks': 11.400327868852452,
#  'Health and Hygiene': 13.142313953488392,
#  'Household': 13.384736495388726,
#  'Meat': 12.81734421364986,
#  'Others': 13.853284671532842,
#  'Seafood': 12.5528431372549,
#  'Snack Foods': 12.987879554655919,
#  'Soft Drinks': 11.847459893048129,
#  'Starchy Foods': 13.690730769230765}

# %%
Item_Type_weight['Fruits and Vegetables']
# Out:
# 13.224769381746881

# %%
data_copy['Item_Weight'].fillna(data_copy['Item_Type'].map(Item_Type_weight),inplace=True)

# %%
data['Item_Weight'].fillna(data['Item_Type'].map(Item_Type_weight),inplace=True)

# %%
data.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat         0.016047
# 1            DRC01     5.920000          Regular         0.019278
# 2            FDN15    17.500000          Low Fat         0.016760
# 3            FDX07    19.200000          Regular         0.000000
# 4            NCD19     8.930000          Low Fat         0.000000
# 5            FDP36    10.395000          Regular         0.000000
# 6            FDO10    13.650000          Regular         0.012741
# 7            FDP10    12.987880          Low Fat         0.127470
# 8            FDH17    16.200000          Regular         0.016687
# 9            FDU28    19.200000          Regular         0.094450
# 10           FDY07    11.800000          Low Fat         0.000000
# 11           FDA03    18.500000          Regular         0.045464
# 12           FDX32    15.100000          Regular         0.100014
# ...

# %%
data_copy.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat         0.016047
# 1            DRC01     5.920000          Regular         0.019278
# 2            FDN15    17.500000          Low Fat         0.016760
# 3            FDX07    19.200000          Regular         0.000000
# 4            NCD19     8.930000          Low Fat         0.000000
# 5            FDP36    10.395000          Regular         0.000000
# 6            FDO10    13.650000          Regular         0.012741
# 7            FDP10    12.987880          Low Fat         0.127470
# 8            FDH17    16.200000          Regular         0.016687
# 9            FDU28    19.200000          Regular         0.094450
# 10           FDY07    11.800000          Low Fat         0.000000
# 11           FDA03    18.500000          Regular         0.045464
# 12           FDX32    15.100000          Regular         0.100014
# ...

# %%
data[data.Outlet_Size.isna()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
data.Outlet_Type.value_counts(dropna=False)
# Out:
# 5    5577
# 4    1083
# 3     935
# 2     928
# Name: Outlet_Type, dtype: int64

# %%
data.groupby(['Outlet_Location_Type','Outlet_Type','Outlet_Size']).Outlet_Size.count()
# Out:
# Outlet_Location_Type  Outlet_Type  Outlet_Size
# Tier 1                4            1.0            528
#                       5            1.0            930
#                                    2.0            930
# Tier 2                5            1.0            930
# Tier 3                2            2.0            928
#                       3            2.0            935
#                       5            3.0            932
# Name: Outlet_Size, dtype: int64

# %%
data.groupby(['Outlet_Location_Type']).Outlet_Size.median()
# Out:
# Outlet_Location_Type
# Tier 1    1.0
# Tier 2    1.0
# Tier 3    2.0
# Name: Outlet_Size, dtype: float64

# %%
data.groupby(['Outlet_Type']).Outlet_Size.value_counts()
# Out:
# Outlet_Type  Outlet_Size
# 2            2.0             928
# 3            2.0             935
# 4            1.0             528
# 5            1.0            1860
#              3.0             932
#              2.0             930
# Name: Outlet_Size, dtype: int64

# %%
data.Outlet_Size.value_counts()
# Out:
# 2.0    2793
# 1.0    2388
# 3.0     932
# Name: Outlet_Size, dtype: int64

# %%
type_dict = dict(data.groupby(['Outlet_Location_Type']).Outlet_Size.median())

# %%
type_dict
# Out:
# {'Tier 1': 1.0, 'Tier 2': 1.0, 'Tier 3': 2.0}

# %%
data_copy['Outlet_Size'].fillna(data_copy['Outlet_Location_Type'].map(type_dict), inplace=True)

# %%
data_copy.head(25)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat         0.016047
# 1            DRC01     5.920000          Regular         0.019278
# 2            FDN15    17.500000          Low Fat         0.016760
# 3            FDX07    19.200000          Regular         0.000000
# 4            NCD19     8.930000          Low Fat         0.000000
# 5            FDP36    10.395000          Regular         0.000000
# 6            FDO10    13.650000          Regular         0.012741
# 7            FDP10    12.987880          Low Fat         0.127470
# 8            FDH17    16.200000          Regular         0.016687
# 9            FDU28    19.200000          Regular         0.094450
# 10           FDY07    11.800000          Low Fat         0.000000
# 11           FDA03    18.500000          Regular         0.045464
# 12           FDX32    15.100000          Regular         0.100014
# ...

# %%
data['Outlet_Size'].fillna(data['Outlet_Location_Type'].map(type_dict), inplace=True)

# %%
data.head(30)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat         0.016047
# 1            DRC01     5.920000          Regular         0.019278
# 2            FDN15    17.500000          Low Fat         0.016760
# 3            FDX07    19.200000          Regular         0.000000
# 4            NCD19     8.930000          Low Fat         0.000000
# 5            FDP36    10.395000          Regular         0.000000
# 6            FDO10    13.650000          Regular         0.012741
# 7            FDP10    12.987880          Low Fat         0.127470
# 8            FDH17    16.200000          Regular         0.016687
# 9            FDU28    19.200000          Regular         0.094450
# 10           FDY07    11.800000          Low Fat         0.000000
# 11           FDA03    18.500000          Regular         0.045464
# 12           FDX32    15.100000          Regular         0.100014
# ...

# %%
numerical_data = data.select_dtypes(include=np.number).drop(columns='Outlet_Type')

# %%
numerical_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Outlet_Size  Item_Outlet_Sales
# 0             2.0          3735.1380
# ...

# %%
numerical_data.columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
categorical_data = data.select_dtypes(exclude=np.number)

# %%
categorical_data
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Location_Type
# 0               OUT049               Tier 1
# 1               OUT018               Tier 3
# 2               OUT049               Tier 1
# 3               OUT010               Tier 3
# ...

# %% [markdown]
# # Perform Standard scaling on Numerical Data (Using Standardisation)

# %%
from sklearn.preprocessing import StandardScaler

# %%
StdScaler = StandardScaler()

# %%
data_num_std = StdScaler.fit_transform(numerical_data )

# %%
data_num_std
# Out:
# array([[-0.84060081, -0.97073217,  1.74745381,  0.13954076,  0.57511938,
#          0.910601  ],
#        [-1.63917263, -0.90811123, -1.48902325,  1.33410274,  0.57511938,
#         -1.01844035],
#        [ 1.0967628 , -0.95691733,  0.01004021,  0.13954076,  0.57511938,
#         -0.04923754],
#        ...,
#        [-0.53345779, -0.59978449, -0.89720755,  0.73682175, -0.90532233,
#         -0.57909963],
#        [-1.33439226,  1.53287976, -0.60797692,  1.33410274,  0.57511938,
#         -0.19672492],
#        [ 0.45885039, -0.41193591, -1.05226104, -0.09937163, -0.90532233,
#         -0.82959407]])

# %%
preprocessed_numerical_data = pd.DataFrame(data_num_std, columns=numerical_data.columns)

# %%
preprocessed_numerical_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0       -0.840601        -0.970732  1.747454                   0.139541
# 1       -1.639173        -0.908111 -1.489023                   1.334103
# 2        1.096763        -0.956917  0.010040                   0.139541
# 3        1.498411        -1.281758  0.660050                   0.020085
# 4       -0.928018        -1.281758 -1.399220                  -1.293934
# ...           ...              ...       ...                        ...
# 8518    -1.415903        -0.181193  1.180783                  -1.293934
# 8519    -1.057964        -0.371154 -0.527301                   0.497909
# 8520    -0.533458        -0.599784 -0.897208                   0.736822
# 8521    -1.334392         1.532880 -0.607977                   1.334103
# 8522     0.458850        -0.411936 -1.052261                  -0.099372
#
#       Outlet_Size  Item_Outlet_Sales
# 0        0.575119           0.910601
# ...

# %% [markdown]
# # One hot encoding on nominal data

# %%
preprocessed_categorical_data = pd.get_dummies(categorical_data)

# %%
preprocessed_categorical_data
# Out:
#       Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                         0                      0                      0
# 1                         0                      0                      0
# 2                         0                      0                      0
# 3                         0                      0                      0
# 4                         0                      0                      0
# ...                     ...                    ...                    ...
# 8518                      0                      0                      0
# 8519                      0                      0                      0
# 8520                      0                      0                      0
# 8521                      0                      0                      0
# 8522                      0                      0                      0
#
#       Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# ...

# %%
total_preprocessed_data = pd.concat((preprocessed_categorical_data, preprocessed_numerical_data, data.Outlet_Type),axis=1)

# %%
total_preprocessed_data
# Out:
#       Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                         0                      0                      0
# 1                         0                      0                      0
# 2                         0                      0                      0
# 3                         0                      0                      0
# 4                         0                      0                      0
# ...                     ...                    ...                    ...
# 8518                      0                      0                      0
# 8519                      0                      0                      0
# 8520                      0                      0                      0
# 8521                      0                      0                      0
# 8522                      0                      0                      0
#
#       Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# ...
